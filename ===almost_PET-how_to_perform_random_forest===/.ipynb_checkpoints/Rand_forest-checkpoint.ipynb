# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %% [markdown]
# Данный расчет выполнен на основе статьи https://habr.com/ru/company/ruvds/blog/488342/ с внесением изменений: добавлением нового раздела, пересмотром и оптимизацией гиперпараметров классификаторов, изменениями в визуализации результатов, переработкой теоретической составляющей работы и другими небольшими изменениями в исходный код статьи.

# %% [markdown]
# # Задача
# Заблаговременное определение раковой опухоли у пациента по имеющимся данным параметров обследования его физического здоровья, наличию схожих заболеваний и вредных привычек (всего 30 независимых переменных).
#
# Для решения задачи был выбран метод машинного обучения Случайных деревьев (Random Forest).

# %% [markdown]
# # Шаги
# 1. Преподготовка данных, разделение на обучающих и тестовые наборы, масштабирование данных.
# 2. Обучение на основе всех имеющихся независимых переменных (НП) с использованием Random Forest (RF).
# 3. Использование метода главных компонент PCA для уменьшения количества НП.
# 4. Обучение методом RF с учетом PCA.
# 5. Оптимизация гиперпараметров метода RF.
# 6. Оценка качества работы модели.

# %% [markdown]
# # Небольшая преподготовка данных

# %%
columns = ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness', 'mean compactness', 'mean concavity', 'mean concave points', 'mean symmetry', 'mean fractal dimension', 'radius error', 'texture error', 'perimeter error', 'area error', 'smoothness error', 'compactness error', 'concavity error', 'concave points error', 'symmetry error', 'fractal dimension error', 'worst radius', 'worst texture', 'worst perimeter', 'worst area', 'worst smoothness', 'worst compactness', 'worst concavity', 'worst concave points', 'worst symmetry', 'worst fractal dimension']
data = load_breast_cancer()
df = pd.DataFrame(data['data'], columns=columns)
df['cancer'] = data['target']

# %% [markdown]
# # Разбиение на обучающий и тестовый наборы

# %%
X = df.drop('cancer', axis=1)
y = df.cancer

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,
    test_size=0.5, random_state=0)

# %% [markdown]
# # Масштабирование данных (стандартизация)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)
y_train = np.array(y_train)

# %% [markdown]
# # Обучение базовой модели

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import recall_score
rfc = RandomForestClassifier()
rfc.fit(X_train_scaled, y_train)
rfc.score(X_train_scaled, y_train)
# Out:
# 1.0

# %%
rfc.feature_importances_
# Out:
# array([0.07183738, 0.0085599 , 0.08415249, 0.03522051, 0.00540002,
#        0.00890503, 0.07945963, 0.1273474 , 0.00504087, 0.00279166,
#        0.01130451, 0.00524459, 0.01621258, 0.01235903, 0.0019128 ,
#        0.00277071, 0.00738674, 0.00480566, 0.00211535, 0.0035087 ,
#        0.09025919, 0.01239366, 0.15704612, 0.11124668, 0.00993233,
#        0.00802409, 0.02584681, 0.06874083, 0.01611912, 0.0040556 ])

# %%
feats = {}
for feature, importance in zip(df.columns, rfc.feature_importances_):
    feats[feature] = importance
importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-Importance'})
importances = importances.sort_values(by='Gini-Importance', ascending=False)
importances = importances.reset_index()
importances = importances.rename(columns={'index': 'Features'})

sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(30,15)
sns.barplot(x=importances['Gini-Importance'], y=importances['Features'], data=importances, color='skyblue')
plt.xlabel('Importance', fontsize=25, weight = 'bold')
plt.ylabel('Features', fontsize=25, weight = 'bold')
plt.title('Feature Importance', fontsize=25, weight = 'bold')
display(plt.show())
# Out:
# None

# %% [markdown]
# # Реализуем метод главных компонент - смотрим какие из переменных оказывают наибольшее влияние на ЗП

# %%
from sklearn.decomposition import PCA

pca_test = PCA(n_components=30)
pca_test.fit(X_train_scaled)

sns.set(style='whitegrid')
plt.plot(np.cumsum(pca_test.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.axvline(linewidth=4, color='r', linestyle = '--', x=10, ymin=0, ymax=1)
display(plt.show())

evr = pca_test.explained_variance_ratio_
cvr = np.cumsum(pca_test.explained_variance_ratio_)
pca_df = pd.DataFrame()
pca_df['Cumulative Variance Ratio'] = cvr
pca_df['Explained Variance Ratio'] = evr
display(pca_df.head(10))
# Out:
# None
#    Cumulative Variance Ratio  Explained Variance Ratio
# 0                   0.445075                  0.445075
# 1                   0.634242                  0.189167
# 2                   0.731652                  0.097410
# 3                   0.798371                  0.066719
# 4                   0.848523                  0.050152
# 5                   0.890047                  0.041524
# 6                   0.915122                  0.025075
# 7                   0.931393                  0.016271
# 8                   0.945976                  0.014583
# 9                   0.957426                  0.011450

# %% [markdown]
# # Оставляем только 10 НП и смотрим веса из РСА компонент

# %%
pca = PCA(n_components=10)
pca.fit(X_train_scaled)
X_train_scaled_pca = pca.transform(X_train_scaled)
X_test_scaled_pca = pca.transform(X_test_scaled)

# %%
pca_dims = []
for x in range(0, len(pca_df)):
    pca_dims.append('PCA Component {}'.format(x))
pca_test_df = pd.DataFrame(pca_test.components_, columns=columns, index=pca_dims)
pca_test_df.head(10).T
# Out:
#                          PCA Component 0  PCA Component 1  PCA Component 2  \
# mean radius                     0.222463        -0.225046        -0.019569
# mean texture                    0.097299        -0.025655         0.131328
# mean perimeter                  0.230266        -0.207507        -0.018796
# mean area                       0.223937        -0.225511         0.019774
# mean smoothness                 0.146040         0.168647        -0.101685
# mean compactness                0.239558         0.155016        -0.073235
# mean concavity                  0.261546         0.038961        -0.015711
# mean concave points             0.258835        -0.043976        -0.038961
# mean symmetry                   0.140340         0.191522        -0.004234
# mean fractal dimension          0.050814         0.367367        -0.030967
# radius error                    0.201156        -0.131437         0.246305
# texture error                   0.016016         0.098356         0.419384
# perimeter error                 0.206848        -0.109940         0.253919
# area error                      0.195491        -0.163572         0.202063
# smoothness error                0.009076         0.193454         0.335340
# compactness error               0.168605         0.237388         0.141957
# concavity error                 0.179280         0.190539         0.152582
# concave points error            0.186504         0.108221         0.210560
# symmetry error                  0.044643         0.166702         0.338923
# fractal dimension error         0.110996         0.286365         0.190112
# worst radius                    0.229431        -0.212666        -0.053678
# worst texture                   0.101192        -0.010082         0.028433
# worst perimeter                 0.238284        -0.191473        -0.054967
# worst area                      0.225970        -0.213668        -0.016666
# worst smoothness                0.119686         0.187342        -0.223412
# worst compactness               0.205088         0.164696        -0.224907
# worst concavity                 0.229171         0.103335        -0.183908
# worst concave points            0.248953        -0.003151        -0.176649
# worst symmetry                  0.116240         0.153637        -0.224721
# worst fractal dimension         0.122033         0.292710        -0.216985
#
#                          PCA Component 3  PCA Component 4  PCA Component 5  \
# mean radius                     0.021692         0.059270         0.011607
# mean texture                   -0.585768        -0.080552        -0.143719
# mean perimeter                  0.024593         0.057229         0.013246
# mean area                       0.040159         0.026013        -0.005510
# mean smoothness                 0.205339        -0.412685        -0.207581
# mean compactness                0.032510         0.009071         0.006564
# mean concavity                  0.038486         0.048366        -0.003799
# mean concave points             0.080113        -0.058844        -0.018637
# mean symmetry                  -0.013789        -0.209812         0.445951
# mean fractal dimension          0.083841        -0.092594        -0.103390
# radius error                    0.119457        -0.163007         0.010605
# texture error                  -0.272507        -0.156687        -0.048538
# perimeter error                 0.111086        -0.108825         0.031074
# area error                      0.124078        -0.120287        -0.017924
# smoothness error                0.146759        -0.212528        -0.267296
# compactness error              -0.036504         0.326986         0.028568
# concavity error                 0.022969         0.352744        -0.022973
# concave points error            0.112217         0.183016        -0.034353
# symmetry error                  0.034579        -0.159664         0.468055
# fractal dimension error         0.028110         0.265240        -0.125041
# worst radius                   -0.019113        -0.003005        -0.007548
# worst texture                  -0.625557        -0.142890        -0.141410
# worst perimeter                -0.019640         0.013798         0.001957
# worst area                     -0.005939        -0.031331        -0.031350
# worst smoothness                0.076677        -0.413770        -0.302337
# worst compactness              -0.110896         0.117370         0.022207
# worst concavity                -0.071161         0.157639        -0.008944
# worst concave points            0.013137         0.001920        -0.032230
# worst symmetry                 -0.149334        -0.192400         0.534799
# worst fractal dimension        -0.061509         0.074284        -0.115933
#
#                          PCA Component 6  PCA Component 7  PCA Component 8  \
# mean radius                    -0.132315         0.071758         0.164330
# mean texture                    0.016023         0.016320        -0.266761
# mean perimeter                 -0.122711         0.057062         0.165227
# mean area                      -0.033142         0.103116         0.146919
# mean smoothness                -0.153209        -0.249310         0.077395
# mean compactness               -0.013720        -0.144640         0.131647
# mean concavity                 -0.066075        -0.040279         0.021431
# mean concave points            -0.167908        -0.118028         0.084824
# mean symmetry                  -0.073032        -0.286447        -0.345844
# mean fractal dimension          0.241809        -0.195579         0.167386
# radius error                    0.330460        -0.058561        -0.167772
# texture error                  -0.149056        -0.303231         0.488036
# perimeter error                 0.338031        -0.108489        -0.140402
# area error                      0.407093         0.008332        -0.169635
# smoothness error               -0.219310         0.573438        -0.154128
# compactness error               0.013039         0.088714        -0.019933
# concavity error                -0.104030         0.065940        -0.229204
# concave points error           -0.393041        -0.255841        -0.298425
# symmetry error                 -0.066408         0.280193         0.311890
# fractal dimension error         0.173236         0.068475         0.151931
# worst radius                   -0.042073         0.083782         0.097109
# worst texture                   0.007187         0.003940        -0.059614
# worst perimeter                -0.027842         0.066157         0.093939
# worst area                      0.056517         0.109342         0.077598
# worst smoothness               -0.082557         0.221842        -0.085778
# worst compactness               0.127997         0.086530         0.079397
# worst concavity                 0.002244         0.081866        -0.048561
# worst concave points           -0.189057        -0.076487        -0.065795
# worst symmetry                  0.001492         0.262683        -0.052098
# worst fractal dimension         0.349158         0.056749         0.150120
#
#                          PCA Component 9
# mean radius                    -0.101420
# mean texture                    0.049158
# mean perimeter                 -0.086346
# mean area                      -0.115478
# mean smoothness                 0.210875
# mean compactness                0.065409
# mean concavity                  0.106491
# mean concave points            -0.031093
# mean symmetry                  -0.504991
# mean fractal dimension         -0.093669
# radius error                    0.075490
# texture error                  -0.068089
# perimeter error                 0.139824
# area error                      0.093251
# smoothness error               -0.262552
# compactness error               0.032152
# concavity error                 0.221318
# concave points error            0.035916
# symmetry error                  0.372795
# fractal dimension error        -0.375184
# worst radius                   -0.152347
# worst texture                   0.047730
# worst perimeter                -0.118838
# worst area                     -0.189364
# worst smoothness                0.076639
# worst compactness               0.143256
# worst concavity                 0.258791
# worst concave points            0.063519
# worst symmetry                 -0.039115
# worst fractal dimension        -0.169414

# %% [markdown]
# # Построение аналогичного biplot с помощью модуля pca

# %%
from pca import pca

# %%
pca_new = pca(n_components=0.95)
results = pca_new.fit_transform(X_train_scaled)
# Out:
# [pca] >Column labels are auto-completed.
# [pca] >Row labels are auto-completed.
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [30] columns of the input data.
# [pca] >Fitting using PCA..
# [pca] >Computing loadings and PCs..
# [pca] >Computing explained variance..
# [pca] >Number of components is [10] that covers the [95.00%] explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[5]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]

# %%
# Plot explained variance
fig, ax = pca_new.plot()

# Scatter first 2 PCs
fig, ax = pca_new.scatter()

# Make biplot with the number of features
fig, ax = pca_new.biplot(n_feat=2, legend=False)

# %%
ax = pca_new.biplot3d(n_feat=4, legend=False, alpha_transparency=0.5)

# %% [markdown]
# # Обучение модели после применения РСА

# %%
rfc_1 = RandomForestClassifier()
rfc_1.fit(X_train_scaled_pca, y_train)
display(rfc_1.score(X_train_scaled_pca, y_train))
# Out:
# 1.0

# %% [markdown]
# # Применяем RandomizedGridSearch

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]
max_features = ['log2', 'sqrt']
max_depth = [int(x) for x in np.linspace(start = 1, stop = 30, num = 15)]
min_samples_split = [int(x) for x in np.linspace(start = 2, stop = 52, num = 10)]
min_samples_leaf = [int(x) for x in np.linspace(start = 2, stop = 27, num = 5)]
bootstrap = [True, False]
param_dist = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
rs = RandomizedSearchCV(rfc_1, 
                        param_dist, 
                        n_iter = 50, 
                        cv = 4, 
                        verbose = 1, 
                        n_jobs=-1, 
                        random_state=0)
rs.fit(X_train_scaled_pca, y_train)
rs.best_params_
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  1.9min finished
# {'n_estimators': 700,
#  'min_samples_split': 18,
#  'min_samples_leaf': 2,
#  'max_features': 'log2',
#  'max_depth': 13,
#  'bootstrap': True}

# %% [markdown]
# # Какие параметры прорабатывал RandGridSearch?

# %%
rs_df = pd.DataFrame(rs.cv_results_).sort_values('rank_test_score').reset_index(drop=True)
rs_df = rs_df.drop([
            'mean_fit_time', 
            'std_fit_time', 
            'mean_score_time',
            'std_score_time', 
            'params', 
            'split0_test_score', 
            'split1_test_score', 
            'split2_test_score', 
            'std_test_score'],
            axis=1)
rs_df.head(10)
# Out:
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                200                      13                     14
# 1                700                      18                      2
# 2               1000                      13                      8
# 3                700                       2                      8
# 4                100                      24                     20
# 5                300                      29                      8
# 6                600                      40                      8
# 7                100                      29                      8
# 8                300                      29                     20
# 9                400                      35                      8
#
#   param_max_features param_max_depth param_bootstrap  split3_test_score  \
# 0               sqrt               9           False           0.943662
# 1               log2              13            True           0.929577
# 2               log2               9           False           0.929577
# 3               sqrt               7           False           0.943662
# 4               sqrt              17           False           0.929577
# 5               log2              19           False           0.929577
# 6               sqrt              19           False           0.943662
# 7               sqrt              30            True           0.929577
# 8               sqrt               9           False           0.915493
# 9               log2               5            True           0.915493
#
#    mean_test_score  rank_test_score
# 0         0.933099                1
# 1         0.933099                1
# 2         0.929577                3
# 3         0.929577                3
# 4         0.929577                3
# 5         0.926056                6
# 6         0.926056                6
# 7         0.926056                6
# 8         0.926056                6
# 9         0.926056                6

# %% [markdown]
# # Графики распределения влияния параметров на результат

# %%
fig, axs = plt.subplots(ncols=3, nrows=2)
sns.set(style="whitegrid", color_codes=True, font_scale = 2)
fig.set_size_inches(30,25)
sns.barplot(x='param_n_estimators', y='mean_test_score', data=rs_df, ax=axs[0,0], color='lightgrey')
axs[0,0].set_ylim([.83,.93])
axs[0,0].set_title(label = 'n_estimators', size=30, weight='bold')
sns.barplot(x='param_min_samples_split', y='mean_test_score', data=rs_df, ax=axs[0,1], color='coral')
axs[0,1].set_ylim([.85,.93])
axs[0,1].set_title(label = 'min_samples_split', size=30, weight='bold')
sns.barplot(x='param_min_samples_leaf', y='mean_test_score', data=rs_df, ax=axs[0,2], color='lightgreen')
axs[0,2].set_ylim([.80,.93])
axs[0,2].set_title(label = 'min_samples_leaf', size=30, weight='bold')
sns.barplot(x='param_max_features', y='mean_test_score', data=rs_df, ax=axs[1,0], color='wheat')
axs[1,0].set_ylim([.88,.92])
axs[1,0].set_title(label = 'max_features', size=30, weight='bold')
sns.barplot(x='param_max_depth', y='mean_test_score', data=rs_df, ax=axs[1,1], color='lightpink')
axs[1,1].set_ylim([.80,.93])
axs[1,1].set_title(label = 'max_depth', size=30, weight='bold')
sns.barplot(x='param_bootstrap',y='mean_test_score', data=rs_df, ax=axs[1,2], color='skyblue')
axs[1,2].set_ylim([.88,.92])
axs[1,2].set_title(label = 'bootstrap', size=30, weight='bold')
plt.show()

# %% [markdown]
# # Применяем GridSearch на лучших параметрах

# %%
from sklearn.model_selection import GridSearchCV
n_estimators = [400,900]
max_features = ['sqrt']
max_depth = [9,17,27]
min_samples_split = [2,13,35]
min_samples_leaf = [2,3,5]
bootstrap = [True]
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
gs = GridSearchCV(rfc_1, param_grid, cv = 4, verbose = 1, n_jobs=-1)
gs.fit(X_train_scaled_pca, y_train)
rfc_gs = gs.best_estimator_
gs.best_params_
# Out:
# Fitting 4 folds for each of 54 candidates, totalling 216 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed:  2.8min finished
# {'bootstrap': True,
#  'max_depth': 17,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 900}

# %% [markdown]
# # Оценка качества на тестовых данных по матрицам ошибок

# %%
y_pred = rfc.predict(X_test_scaled)
y_pred_pca = rfc_1.predict(X_test_scaled_pca)
y_pred_gs = gs.best_estimator_.predict(X_test_scaled_pca)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
conf_matrix_baseline = pd.DataFrame(confusion_matrix(y_test, y_pred), index = ['actual 0', 'actual 1'], columns = ['predicted 0', 'predicted 1'])
conf_matrix_baseline_pca = pd.DataFrame(confusion_matrix(y_test, y_pred_pca), index = ['actual 0', 'actual 1'], columns = ['predicted 0', 'predicted 1'])
conf_matrix_tuned_pca = pd.DataFrame(confusion_matrix(y_test, y_pred_gs), index = ['actual 0', 'actual 1'], columns = ['predicted 0', 'predicted 1'])
display(conf_matrix_baseline)
display('Baseline Random Forest recall score', recall_score(y_test, y_pred))
display('F1 score', f1_score(y_test, y_pred))
display(conf_matrix_baseline_pca)
display('Baseline Random Forest With PCA recall score', recall_score(y_test, y_pred_pca))
display('F1 score', f1_score(y_test, y_pred_pca))
display(conf_matrix_tuned_pca)
display('Hyperparameter Tuned Random Forest With PCA Reduced Dimensionality recall score', recall_score(y_test, y_pred_gs))
display('F1 score', f1_score(y_test, y_pred_gs))
# Out:
#           predicted 0  predicted 1
# actual 0           99            7
# actual 1           10          169
# 'Baseline Random Forest recall score'
# 0.9441340782122905
# 'F1 score'
# 0.952112676056338
#           predicted 0  predicted 1
# actual 0           98            8
# actual 1            8          171
# 'Baseline Random Forest With PCA recall score'
# 0.9553072625698324
# 'F1 score'
# 0.9553072625698324
#           predicted 0  predicted 1
# actual 0           97            9
# actual 1            9          170
# 'Hyperparameter Tuned Random Forest With PCA Reduced Dimensionality recall score'
# 0.9497206703910615
# 'F1 score'
# 0.9497206703910615

# %% [markdown]
# # Вывод:

# %% [markdown]
# Для данной задачи наиболее важна метрика recall, т.к. нам важно как можно реже пропускать пациентов FN с раком (ложные срабатывания FP допустимы). Исходя из этого можно сделать вывод, что вторая модель (RF с учетом PCA) показала наилучший результат.
#
# Но стоит отметить, что разница между полученными зачениями Recall оказалась невелика, что объясняется малым размером выборки (влияние PCA слабоощутимо). Применение PCA оправданно в случае работы с большими объемами данных для ускорения вычислений без потери в качестве модели.
